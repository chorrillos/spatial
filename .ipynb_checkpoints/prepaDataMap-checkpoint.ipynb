# %% [markdown]
# ## Descargando mapa y data:

# %%
import geopandas as gpd

link="https://github.com/chorrillos/spatial/raw/main/worldMap.geojson"
WorldMap=gpd.read_file(link)
WorldMap
# Out:
#     FIPS ISO2 ISO3   UN                                  NAME    AREA  \
# 0     AC   AG  ATG   28                   Antigua and Barbuda      44
# 1     AG   DZ  DZA   12                               Algeria  238174
# 2     AJ   AZ  AZE   31                            Azerbaijan    8260
# 3     AL   AL  ALB    8                               Albania    2740
# 4     AM   AM  ARM   51                               Armenia    2820
# ..   ...  ...  ...  ...                                   ...     ...
# 241   TB   BL  BLM  652                      Saint Barthelemy       0
# 242   GK   GG  GGY  831                              Guernsey       0
# 243   JE   JE  JEY  832                                Jersey       0
# 244   SX   GS  SGS  239  South Georgia South Sandwich Islands       0
# 245   TW   TW  TWN  158                                Taiwan       0
#
#       POP2005  REGION  SUBREGION      LON     LAT  \
# 0       83039      19         29  -61.783  17.078
# 1    32854159       2         15    2.632  28.163
# 2     8352021     142        145   47.395  40.430
# 3     3153731     150         39   20.068  41.143
# 4     3017661     142        145   44.563  40.534
# ..        ...     ...        ...      ...     ...
# 241         0      19         29  -63.043  18.040
# 242         0     150        154   -2.576  49.459
# 243         0     150        154   -2.129  49.219
# 244         0       0          0  -36.891 -54.209
# 245         0       0          0  120.946  23.754
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.68667 17.02444, -61.88722 ...
# 1    POLYGON ((2.96361 36.80222, 4.78583 36.89472, ...
# 2    MULTIPOLYGON (((45.08332 39.76805, 45.81999 39...
# 3    POLYGON ((19.43621 41.02107, 19.60055 41.79666...
# 4    POLYGON ((45.15387 41.19860, 46.00194 40.22555...
# ..                                                 ...
# 241  POLYGON ((-63.02834 18.01555, -63.13984 18.058...
# 242  POLYGON ((-2.59083 49.42249, -2.67028 49.43417...
# 243  POLYGON ((-2.01500 49.21417, -2.20528 49.18083...
# 244  MULTIPOLYGON (((-27.32584 -59.42722, -27.29806...
# 245  MULTIPOLYGON (((121.57639 22.00139, 121.49026 ...
#
# [246 rows x 12 columns]

# %%
import pandas as pd
link2="https://github.com/xmarquez/democracyData/raw/master/data-raw/EIU%20Democracy%20Index%202020.csv"
datademo=pd.read_csv(link2)
datademo
# Out:
#        country   eiu  year
# 0       Canada  8.87  2021
# 1       Canada  9.24  2020
# 2       Canada  9.22  2019
# 3       Canada  9.15  2018
# 4       Canada  9.15  2017
# ...        ...   ...   ...
# 2333  Zimbabwe  2.67  2012
# 2334  Zimbabwe  2.68  2011
# 2335  Zimbabwe  2.64  2010
# 2336  Zimbabwe  2.53  2008
# 2337  Zimbabwe  2.62  2006
#
# [2338 rows x 3 columns]

# %%
# data 2021
#install bs4 y html5lib
link3="https://en.wikipedia.org/wiki/Democracy_Index"
data2021=pd.read_html(link3,flavor='bs4',header=0)[6]
data2021
# Out:
#                  Rank  \
# 0    Full democracies
# 1                   1
# 2                   2
# 3                   3
# 4                   4
# ..                ...
# 166               162
# 167               164
# 168               165
# 169               166
# 170               167
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Δ Rank  \
# 0                                     Full democracies
# 1                                                  NaN
# 2                                                    2
# 3                                                    3
# 4                                                    1
# ..                                                 ...
# 166                                                  2
# 167                                                  2
# 168                                                  2
# 169                                                 31
# 170                                                 28
#
#                               Country       Regime type     Overall score  \
# 0                    Full democracies  Full democracies  Full democracies
# 1                              Norway    Full democracy              9.75
# 2                         New Zealand    Full democracy              9.37
# 3                             Finland    Full democracy              9.27
# 4                              Sweden    Full democracy              9.26
# ..                                ...               ...               ...
# 166          Central African Republic     Authoritarian              1.43
# 167  Democratic Republic of the Congo     Authoritarian              1.40
# 168                       North Korea     Authoritarian              1.08
# 169                           Myanmar     Authoritarian              1.02
# 170                       Afghanistan     Authoritarian              0.32
#
#               Δ Score Elec­toral pro­cessand plura­lism  \
# 0    Full democracies                  Full democracies
# 1                0.06                             10.00
# 2                0.12                             10.00
# 3                0.07                             10.00
# 4                 NaN                              9.58
# ..                ...                               ...
# 166              0.11                              1.25
# 167              0.27                              0.75
# 168               NaN                              0.00
# 169              2.04                              0.00
# 170              2.53                              0.00
#
#     Func­tioningof govern­ment Poli­ticalpartici­pation Poli­ticalcul­ture  \
# 0             Full democracies         Full democracies   Full democracies
# 1                         9.64                    10.00              10.00
# 2                         8.93                     8.89               8.75
# 3                         9.29                     8.89               8.75
# 4                         9.29                     8.33              10.00
# ..                         ...                      ...                ...
# 166                       0.00                     1.67               1.88
# 167                       0.00                     2.22               3.13
# 168                       2.50                     1.67               1.25
# 169                       0.00                     1.67               3.13
# 170                       0.07                     0.00               1.25
#
#       Civilliber­ties
# 0    Full democracies
# 1                9.12
# 2                9.71
# 3                9.41
# 4                9.12
# ..                ...
# 166              2.35
# 167              0.88
# 168              0.00
# 169              0.29
# 170              0.29
#
# [171 rows x 11 columns]

# %%
datademo=datademo.pivot(index='country', columns='year', values='eiu')
datademo.reset_index(inplace=True)
datademo
# Out:
# year      country  2006  2008  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0     Afghanistan  3.06  3.02  2.48  2.48  2.48  2.48  2.77  2.77  2.55  2.55
# 1         Albania  5.91  5.91  5.86  5.81  5.67  5.67  5.67  5.91  5.91  5.98
# 2         Algeria  3.17  3.32  3.44  3.44  3.83  3.83  3.83  3.95  3.56  3.56
# 3          Angola  2.41  3.35  3.32  3.32  3.35  3.35  3.35  3.35  3.40  3.62
# 4       Argentina  6.63  6.63  6.84  6.84  6.84  6.84  6.84  7.02  6.96  6.96
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 162       Vietnam  2.75  2.53  2.94  2.96  2.89  3.29  3.41  3.53  3.38  3.08
# 163         Yemen  2.98  2.95  2.64  2.57  3.12  2.79  2.79  2.24  2.07  2.07
# 164        Zambia  5.25  5.25  5.68  6.19  6.26  6.26  6.39  6.28  5.99  5.68
# 165      Zimbabwe  2.62  2.53  2.64  2.68  2.67  2.67  2.78  3.05  3.05  3.16
# 166      eSwatini  2.93  3.04  2.90  3.26  3.20  3.20  3.09  3.09  3.03  3.03
#
# year  2018  2019  2020  2021
# 0     2.97  2.85  2.85  0.32
# 1     5.98  5.89  6.08  6.11
# 2     3.50  4.01  3.77  3.77
# 3     3.62  3.72  3.66  3.37
# 4     7.02  7.02  6.95  6.81
# ..     ...   ...   ...   ...
# 162   3.08  3.08  2.94  2.94
# 163   1.95  1.95  1.95  1.95
# 164   5.61  5.09  4.86  5.72
# 165   3.16  3.16  3.16  2.92
# 166   3.03  3.14  3.08  3.08
#
# [167 rows x 15 columns]

# %%
datademo.columns
# Out:
# Index(['country',      2006,      2008,      2010,      2011,      2012,
#             2013,      2014,      2015,      2016,      2017,      2018,
#             2019,      2020,      2021],
#       dtype='object', name='year')

# %%
datademo.columns=[str(y) for y in datademo.columns]
datademo.columns
# Out:
# Index(['country', '2006', '2008', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
datademo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  167 non-null    object
#  1   2006     167 non-null    float64
#  2   2008     167 non-null    float64
#  3   2010     167 non-null    float64
#  4   2011     167 non-null    float64
#  5   2012     167 non-null    float64
#  6   2013     167 non-null    float64
#  7   2014     167 non-null    float64
#  8   2015     167 non-null    float64
#  9   2016     167 non-null    float64
#  10  2017     167 non-null    float64
#  11  2018     167 non-null    float64
#  12  2019     167 non-null    float64
#  13  2020     167 non-null    float64
#  14  2021     167 non-null    float64
# dtypes: float64(14), object(1)
# memory usage: 19.7+ KB

# %%
data2021.columns
# Out:
# Index(['Rank',
#        '.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Δ Rank',
#        'Country', 'Regime type', 'Overall score', 'Δ Score',
#        'Elec­toral pro­cessand plura­lism', 'Func­tioningof govern­ment',
#        'Poli­ticalpartici­pation', 'Poli­ticalcul­ture', 'Civilliber­ties'],
#       dtype='object')

# %%
data2021.drop(data2021.columns[[0,1,3,4,5]],axis=1,inplace=True)
data2021
# Out:
#                               Country Elec­toral pro­cessand plura­lism  \
# 0                    Full democracies                  Full democracies
# 1                              Norway                             10.00
# 2                         New Zealand                             10.00
# 3                             Finland                             10.00
# 4                              Sweden                              9.58
# ..                                ...                               ...
# 166          Central African Republic                              1.25
# 167  Democratic Republic of the Congo                              0.75
# 168                       North Korea                              0.00
# 169                           Myanmar                              0.00
# 170                       Afghanistan                              0.00
#
#     Func­tioningof govern­ment Poli­ticalpartici­pation Poli­ticalcul­ture  \
# 0             Full democracies         Full democracies   Full democracies
# 1                         9.64                    10.00              10.00
# 2                         8.93                     8.89               8.75
# 3                         9.29                     8.89               8.75
# 4                         9.29                     8.33              10.00
# ..                         ...                      ...                ...
# 166                       0.00                     1.67               1.88
# 167                       0.00                     2.22               3.13
# 168                       2.50                     1.67               1.25
# 169                       0.00                     1.67               3.13
# 170                       0.07                     0.00               1.25
#
#       Civilliber­ties
# 0    Full democracies
# 1                9.12
# 2                9.71
# 3                9.41
# 4                9.12
# ..                ...
# 166              2.35
# 167              0.88
# 168              0.00
# 169              0.29
# 170              0.29
#
# [171 rows x 6 columns]

# %%
data2021.columns.to_list()
# Out:
# ['Country',
#  'Elec\xadtoral pro\xadcessand plura\xadlism',
#  'Func\xadtioningof govern\xadment',
#  'Poli\xadticalpartici\xadpation',
#  'Poli\xadticalcul\xadture',
#  'Civilliber\xadties']

# %%
data2021.columns.str.replace('\N{SOFT HYPHEN}|\s', '',regex=True).str.lower().to_list()
# Out:
# ['country',
#  'electoralprocessandpluralism',
#  'functioningofgovernment',
#  'politicalparticipation',
#  'politicalculture',
#  'civilliberties']

# %%
data2021.columns=data2021.columns.str.replace('\N{SOFT HYPHEN}|\s', '',regex=True).str.lower().to_list()
data2021.columns
# Out:
# Index(['country', 'electoralprocessandpluralism', 'functioningofgovernment',
#        'politicalparticipation', 'politicalculture', 'civilliberties'],
#       dtype='object')

# %%
datademo.merge(data2021)
# Out:
#          country  2006  2008  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0    Afghanistan  3.06  3.02  2.48  2.48  2.48  2.48  2.77  2.77  2.55  2.55
# 1        Albania  5.91  5.91  5.86  5.81  5.67  5.67  5.67  5.91  5.91  5.98
# 2        Algeria  3.17  3.32  3.44  3.44  3.83  3.83  3.83  3.95  3.56  3.56
# 3         Angola  2.41  3.35  3.32  3.32  3.35  3.35  3.35  3.35  3.40  3.62
# 4      Argentina  6.63  6.63  6.84  6.84  6.84  6.84  6.84  7.02  6.96  6.96
# ..           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 151    Venezuela  5.42  5.34  5.18  5.08  5.15  5.07  5.07  5.00  4.68  3.87
# 152      Vietnam  2.75  2.53  2.94  2.96  2.89  3.29  3.41  3.53  3.38  3.08
# 153        Yemen  2.98  2.95  2.64  2.57  3.12  2.79  2.79  2.24  2.07  2.07
# 154       Zambia  5.25  5.25  5.68  6.19  6.26  6.26  6.39  6.28  5.99  5.68
# 155     Zimbabwe  2.62  2.53  2.64  2.68  2.67  2.67  2.78  3.05  3.05  3.16
#
#      2018  2019  2020  2021 electoralprocessandpluralism  \
# 0    2.97  2.85  2.85  0.32                         0.00
# 1    5.98  5.89  6.08  6.11                         7.00
# 2    3.50  4.01  3.77  3.77                         3.08
# 3    3.62  3.72  3.66  3.37                         1.33
# 4    7.02  7.02  6.95  6.81                         9.17
# ..    ...   ...   ...   ...                          ...
# 151  3.16  2.88  2.76  2.11                         0.00
# 152  3.08  3.08  2.94  2.94                         0.00
# 153  1.95  1.95  1.95  1.95                         0.00
# 154  5.61  5.09  4.86  5.72                         7.50
# 155  3.16  3.16  3.16  2.92                         0.00
#
#     functioningofgovernment politicalparticipation politicalculture  \
# 0                      0.07                   0.00             1.25
# 1                      6.43                   4.44             5.63
# 2                      2.50                   4.44             5.00
# 3                      2.86                   5.00             5.00
# 4                      5.00                   7.22             5.00
# ..                      ...                    ...              ...
# 151                    1.79                   3.89             2.50
# 152                    2.86                   3.89             5.63
# 153                    0.00                   3.89             5.00
# 154                    3.64                   5.00             6.88
# 155                    2.50                   3.89             5.00
#
#     civilliberties
# 0             0.29
# 1             7.06
# 2             3.82
# 3             2.65
# 4             7.65
# ..             ...
# 151           2.35
# 152           2.35
# 153           0.88
# 154           5.59
# 155           3.24
#
# [156 rows x 20 columns]

# %%
sinmatchDATA=list(set(datademo.country)- set(data2021.country))
sinmatch2021=list(set(data2021.country)-set(datademo.country) )
len(sinmatchDATA), len(sinmatch2021)
# Out:
# (6, 10)

# %%
from thefuzz import process
[(process.extractOne(country,sinmatch2021),country) for country in sorted(sinmatchDATA)]
# Out:
# [(('Bosnia and Herzegovina', 95), 'Bosnia and Hercegovina'),
#  (('Cape Verde', 80), 'Cabo Verde'),
#  (('Ivory Coast', 58), 'Côte d’Ivoire'),
#  (('Democratic Republic of the Congo', 95), 'Democratic Republic of Congo'),
#  (('East Timor', 82), 'Timor Leste'),
#  (('Eswatini', 100), 'eSwatini')]

# %%
data2021[data2021.country.str.contains("Kyr")]
# Out:
#         country electoralprocessandpluralism functioningofgovernment  \
# 118  Kyrgyzstan                         4.33                    1.50
#
#     politicalparticipation politicalculture civilliberties
# 118                   4.44             5.00           3.82

# %%
data2021.loc[data2021.country=="Republic of the Congo","country"]="Congo (Brazzaville)"
data2021.loc[data2021.country=="United Arab Emirates","country"]="UAE"
data2021.loc[data2021.country=="United Kingdom","country"]="UK"
data2021.loc[data2021.country=="United States","country"]="US"
data2021.loc[data2021.country=="Kyrgyzstan","country"]="Kyrgyz Republic"

# %%
# dict de cambios:
cambios2021Name={process.extractOne(country,sinmatch2021)[0]:country for country in sorted(sinmatchDATA)}
cambios2021Name
# Out:
# {'Bosnia and Herzegovina': 'Bosnia and Hercegovina',
#  'Cape Verde': 'Cabo Verde',
#  'Ivory Coast': 'Côte d’Ivoire',
#  'Democratic Republic of the Congo': 'Democratic Republic of Congo',
#  'East Timor': 'Timor Leste',
#  'Eswatini': 'eSwatini'}

# %%
# ejecutando cambios 
data2021.country.replace(cambios2021Name,inplace=True)
data2021
# Out:
#                           country electoralprocessandpluralism  \
# 0                Full democracies             Full democracies
# 1                          Norway                        10.00
# 2                     New Zealand                        10.00
# 3                         Finland                        10.00
# 4                          Sweden                         9.58
# ..                            ...                          ...
# 166      Central African Republic                         1.25
# 167  Democratic Republic of Congo                         0.75
# 168                   North Korea                         0.00
# 169                       Myanmar                         0.00
# 170                   Afghanistan                         0.00
#
#     functioningofgovernment politicalparticipation  politicalculture  \
# 0          Full democracies       Full democracies  Full democracies
# 1                      9.64                  10.00             10.00
# 2                      8.93                   8.89              8.75
# 3                      9.29                   8.89              8.75
# 4                      9.29                   8.33             10.00
# ..                      ...                    ...               ...
# 166                    0.00                   1.67              1.88
# 167                    0.00                   2.22              3.13
# 168                    2.50                   1.67              1.25
# 169                    0.00                   1.67              3.13
# 170                    0.07                   0.00              1.25
#
#        civilliberties
# 0    Full democracies
# 1                9.12
# 2                9.71
# 3                9.41
# 4                9.12
# ..                ...
# 166              2.35
# 167              0.88
# 168              0.00
# 169              0.29
# 170              0.29
#
# [171 rows x 6 columns]

# %%
datademo.merge(data2021)
# Out:
#          country  2006  2008  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0    Afghanistan  3.06  3.02  2.48  2.48  2.48  2.48  2.77  2.77  2.55  2.55
# 1        Albania  5.91  5.91  5.86  5.81  5.67  5.67  5.67  5.91  5.91  5.98
# 2        Algeria  3.17  3.32  3.44  3.44  3.83  3.83  3.83  3.95  3.56  3.56
# 3         Angola  2.41  3.35  3.32  3.32  3.35  3.35  3.35  3.35  3.40  3.62
# 4      Argentina  6.63  6.63  6.84  6.84  6.84  6.84  6.84  7.02  6.96  6.96
# ..           ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 162      Vietnam  2.75  2.53  2.94  2.96  2.89  3.29  3.41  3.53  3.38  3.08
# 163        Yemen  2.98  2.95  2.64  2.57  3.12  2.79  2.79  2.24  2.07  2.07
# 164       Zambia  5.25  5.25  5.68  6.19  6.26  6.26  6.39  6.28  5.99  5.68
# 165     Zimbabwe  2.62  2.53  2.64  2.68  2.67  2.67  2.78  3.05  3.05  3.16
# 166     eSwatini  2.93  3.04  2.90  3.26  3.20  3.20  3.09  3.09  3.03  3.03
#
#      2018  2019  2020  2021 electoralprocessandpluralism  \
# 0    2.97  2.85  2.85  0.32                         0.00
# 1    5.98  5.89  6.08  6.11                         7.00
# 2    3.50  4.01  3.77  3.77                         3.08
# 3    3.62  3.72  3.66  3.37                         1.33
# 4    7.02  7.02  6.95  6.81                         9.17
# ..    ...   ...   ...   ...                          ...
# 162  3.08  3.08  2.94  2.94                         0.00
# 163  1.95  1.95  1.95  1.95                         0.00
# 164  5.61  5.09  4.86  5.72                         7.50
# 165  3.16  3.16  3.16  2.92                         0.00
# 166  3.03  3.14  3.08  3.08                         0.92
#
#     functioningofgovernment politicalparticipation politicalculture  \
# 0                      0.07                   0.00             1.25
# 1                      6.43                   4.44             5.63
# 2                      2.50                   4.44             5.00
# 3                      2.86                   5.00             5.00
# 4                      5.00                   7.22             5.00
# ..                      ...                    ...              ...
# 162                    2.86                   3.89             5.63
# 163                    0.00                   3.89             5.00
# 164                    3.64                   5.00             6.88
# 165                    2.50                   3.89             5.00
# 166                    2.86                   2.78             5.63
#
#     civilliberties
# 0             0.29
# 1             7.06
# 2             3.82
# 3             2.65
# 4             7.65
# ..             ...
# 162           2.35
# 163           0.88
# 164           5.59
# 165           3.24
# 166           3.24
#
# [167 rows x 20 columns]

# %%
datademo=datademo.merge(data2021)

# %%
sinmatchDATA=list(set(datademo.country)- set(WorldMap.NAME))
sinmatchMAP=list(set(WorldMap.NAME)-set(datademo.country) )
len(sinmatchDATA), len(sinmatchMAP)
# Out:
# (22, 101)

# %%
from thefuzz import process
[(process.extractOne(country,sinmatchMAP),country) for country in sorted(sinmatchDATA)]
# Out:
# [(('Bosnia and Herzegovina', 95), 'Bosnia and Hercegovina'),
#  (('Cape Verde', 80), 'Cabo Verde'),
#  (('Congo', 90), 'Congo (Brazzaville)'),
#  (("Cote d'Ivoire", 96), 'Côte d’Ivoire'),
#  (('Democratic Republic of the Congo', 95), 'Democratic Republic of Congo'),
#  (('Iran (Islamic Republic of)', 90), 'Iran'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'Kyrgyz Republic'),
#  (('Barbados', 68), 'Laos'),
#  (('Libyan Arab Jamahiriya', 90), 'Libya'),
#  (('Republic of Moldova', 90), 'Moldova'),
#  (('Libyan Arab Jamahiriya', 64), 'Myanmar'),
#  (('Korea, Republic of', 86), 'North Korea'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'North Macedonia'),
#  (('South Georgia South Sandwich Islands', 86), 'South Korea'),
#  (('Syrian Arab Republic', 90), 'Syria'),
#  (('United Republic of Tanzania', 90), 'Tanzania'),
#  (('Timor-Leste', 100), 'Timor Leste'),
#  (('French Guiana', 60), 'UAE'),
#  (('Guam', 45), 'UK'),
#  (('Brunei Darussalam', 60), 'US'),
#  (('Viet Nam', 93), 'Vietnam'),
#  (('Swaziland', 59), 'eSwatini')]

# %% [markdown]
# ## Corrigiendo texto clave

# %%
WorldMap.loc[WorldMap.NAME=="Kyrgyzstan","NAME"]="Kyrgyz Republic"
WorldMap.loc[WorldMap.NAME=="Korea, Democratic People's Republic of","NAME"]="North Korea"
WorldMap.loc[WorldMap.NAME=="Korea, Republic of","NAME"]="South Korea"
WorldMap.loc[WorldMap.NAME=="Burma","NAME"]="Myanmar"
WorldMap.loc[WorldMap.NAME=="United Arab Emirates","NAME"]="UAE"
WorldMap.loc[WorldMap.NAME=="United Kingdom","NAME"]="UK"
WorldMap.loc[WorldMap.NAME=="United States","NAME"]="US"

# %%
sinmatchDATA=list(set(datademo.country)- set(WorldMap.NAME))
sinmatchMAP=list(set(WorldMap.NAME)-set(datademo.country) )
len(sinmatchDATA), len(sinmatchMAP)
# Out:
# (15, 94)

# %%
[(process.extractOne(country,sinmatchMAP),country) for country in sorted(sinmatchDATA)]
# Out:
# [(('Bosnia and Herzegovina', 95), 'Bosnia and Hercegovina'),
#  (('Cape Verde', 80), 'Cabo Verde'),
#  (('Congo', 90), 'Congo (Brazzaville)'),
#  (("Cote d'Ivoire", 96), 'Côte d’Ivoire'),
#  (('Democratic Republic of the Congo', 95), 'Democratic Republic of Congo'),
#  (('Iran (Islamic Republic of)', 90), 'Iran'),
#  (('Barbados', 68), 'Laos'),
#  (('Libyan Arab Jamahiriya', 90), 'Libya'),
#  (('Republic of Moldova', 90), 'Moldova'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'North Macedonia'),
#  (('Syrian Arab Republic', 90), 'Syria'),
#  (('United Republic of Tanzania', 90), 'Tanzania'),
#  (('Timor-Leste', 100), 'Timor Leste'),
#  (('Viet Nam', 93), 'Vietnam'),
#  (('Swaziland', 59), 'eSwatini')]

# %%
# dict de cambios:
cambiosMapaName={process.extractOne(country,sinmatchMAP)[0]:country for country in sorted(sinmatchDATA)}
cambiosMapaName
# Out:
# {'Bosnia and Herzegovina': 'Bosnia and Hercegovina',
#  'Cape Verde': 'Cabo Verde',
#  'Congo': 'Congo (Brazzaville)',
#  "Cote d'Ivoire": 'Côte d’Ivoire',
#  'Democratic Republic of the Congo': 'Democratic Republic of Congo',
#  'Iran (Islamic Republic of)': 'Iran',
#  'Barbados': 'Laos',
#  'Libyan Arab Jamahiriya': 'Libya',
#  'Republic of Moldova': 'Moldova',
#  'The former Yugoslav Republic of Macedonia': 'North Macedonia',
#  'Syrian Arab Republic': 'Syria',
#  'United Republic of Tanzania': 'Tanzania',
#  'Timor-Leste': 'Timor Leste',
#  'Viet Nam': 'Vietnam',
#  'Swaziland': 'eSwatini'}

# %%
# ejecutando cambios 
WorldMap.NAME.replace(cambiosMapaName,inplace=True)
WorldMap
# Out:
#     FIPS ISO2 ISO3   UN                                  NAME    AREA  \
# 0     AC   AG  ATG   28                   Antigua and Barbuda      44
# 1     AG   DZ  DZA   12                               Algeria  238174
# 2     AJ   AZ  AZE   31                            Azerbaijan    8260
# 3     AL   AL  ALB    8                               Albania    2740
# 4     AM   AM  ARM   51                               Armenia    2820
# ..   ...  ...  ...  ...                                   ...     ...
# 241   TB   BL  BLM  652                      Saint Barthelemy       0
# 242   GK   GG  GGY  831                              Guernsey       0
# 243   JE   JE  JEY  832                                Jersey       0
# 244   SX   GS  SGS  239  South Georgia South Sandwich Islands       0
# 245   TW   TW  TWN  158                                Taiwan       0
#
#       POP2005  REGION  SUBREGION      LON     LAT  \
# 0       83039      19         29  -61.783  17.078
# 1    32854159       2         15    2.632  28.163
# 2     8352021     142        145   47.395  40.430
# 3     3153731     150         39   20.068  41.143
# 4     3017661     142        145   44.563  40.534
# ..        ...     ...        ...      ...     ...
# 241         0      19         29  -63.043  18.040
# 242         0     150        154   -2.576  49.459
# 243         0     150        154   -2.129  49.219
# 244         0       0          0  -36.891 -54.209
# 245         0       0          0  120.946  23.754
#
#                                               geometry
# 0    MULTIPOLYGON (((-61.68667 17.02444, -61.88722 ...
# 1    POLYGON ((2.96361 36.80222, 4.78583 36.89472, ...
# 2    MULTIPOLYGON (((45.08332 39.76805, 45.81999 39...
# 3    POLYGON ((19.43621 41.02107, 19.60055 41.79666...
# 4    POLYGON ((45.15387 41.19860, 46.00194 40.22555...
# ..                                                 ...
# 241  POLYGON ((-63.02834 18.01555, -63.13984 18.058...
# 242  POLYGON ((-2.59083 49.42249, -2.67028 49.43417...
# 243  POLYGON ((-2.01500 49.21417, -2.20528 49.18083...
# 244  MULTIPOLYGON (((-27.32584 -59.42722, -27.29806...
# 245  MULTIPOLYGON (((121.57639 22.00139, 121.49026 ...
#
# [246 rows x 12 columns]

# %% [markdown]
# ## Preparando mapa

# %%
# merge hacia MAPA
WorldMap=WorldMap.merge(datademo, left_on='NAME', right_on="country")

# %%
WorldMap
# Out:
#     FIPS ISO2 ISO3   UN         NAME    AREA    POP2005  REGION  SUBREGION  \
# 0     AG   DZ  DZA   12      Algeria  238174   32854159       2         15
# 1     AJ   AZ  AZE   31   Azerbaijan    8260    8352021     142        145
# 2     AL   AL  ALB    8      Albania    2740    3153731     150         39
# 3     AM   AM  ARM   51      Armenia    2820    3017661     142        145
# 4     AO   AO  AGO   24       Angola  124670   16095214       2         17
# ..   ...  ...  ...  ...          ...     ...        ...     ...        ...
# 162   ID   ID  IDN  360    Indonesia  181157  226063044     142         35
# 163   AE   AE  ARE  784          UAE    8360    4104291     142        145
# 164   TT   TL  TLS  626  Timor Leste    1487    1067285     142         35
# 165   RB   RS  SRB  688       Serbia       0    9863026     150         39
# 166   TW   TW  TWN  158       Taiwan       0          0       0          0
#
#          LON  ...  2017  2018  2019  2020  2021  electoralprocessandpluralism  \
# 0      2.632  ...  3.56  3.50  4.01  3.77  3.77                          3.08
# 1     47.395  ...  2.65  2.65  2.75  2.68  2.68                          0.50
# 2     20.068  ...  5.98  5.98  5.89  6.08  6.11                          7.00
# 3     44.563  ...  4.11  4.79  5.54  5.35  5.49                          7.50
# 4     17.544  ...  3.62  3.62  3.72  3.66  3.37                          1.33
# ..       ...  ...   ...   ...   ...   ...   ...                           ...
# 162  114.252  ...  6.39  6.39  6.48  6.30  6.71                          7.92
# 163   54.163  ...  2.69  2.76  2.76  2.70  2.90                          0.00
# 164  125.878  ...  7.19  7.19  7.19  7.06  7.06                          9.58
# 165   20.806  ...  6.41  6.41  6.41  6.22  6.36                          8.25
# 166  120.946  ...  7.73  7.73  7.73  8.94  8.99                         10.00
#
#      functioningofgovernment  politicalparticipation  politicalculture  \
# 0                       2.50                    4.44              5.00
# 1                       2.86                    3.33              3.75
# 2                       6.43                    4.44              5.63
# 3                       5.00                    6.11              3.13
# 4                       2.86                    5.00              5.00
# ..                       ...                     ...               ...
# 162                     7.86                    7.22              4.38
# 163                     4.29                    2.22              5.63
# 164                     5.93                    5.56              6.88
# 165                     5.36                    6.67              3.75
# 166                     9.64                    7.78              8.13
#
#      civilliberties
# 0              3.82
# 1              2.94
# 2              7.06
# 3              5.00
# 4              2.65
# ..              ...
# 162            6.18
# 163            2.35
# 164            7.35
# 165            7.06
# 166            9.41
#
# [167 rows x 32 columns]

# %%
# guardando data
WorldMap.to_file("WorldMapDemo.gpkg", layer='DISTRITO', driver="GPKG")

# %% [markdown]
# ## Descargando mapa y data:

# %%
import geopandas as gpd

link="https://github.com/chorrillos/spatial/raw/main/worldMap.geojson"
WorldMap=gpd.read_file(link)

# %%
WorldMap
# Out:
#     FIPS ISO2 ISO3   UN                                  NAME    AREA  \
# 0     AC   AG  ATG   28                   Antigua and Barbuda      44
# 1     AG   DZ  DZA   12                               Algeria  238174
# 2     AJ   AZ  AZE   31                            Azerbaijan    8260
# 3     AL   AL  ALB    8                               Albania    2740
# 4     AM   AM  ARM   51                               Armenia    2820
# ..   ...  ...  ...  ...                                   ...     ...
# 241   TB   BL  BLM  652                      Saint Barthelemy       0
# 242   GK   GG  GGY  831                              Guernsey       0
# 243   JE   JE  JEY  832                                Jersey       0
# 244   SX   GS  SGS  239  South Georgia South Sandwich Islands       0
# 245   TW   TW  TWN  158                                Taiwan       0
#
#       POP2005  REGION  SUBREGION      LON     LAT  \
# 0       83039      19         29  -61.783  17.078
# ...

# %%
import pandas as pd
link2="https://github.com/xmarquez/democracyData/raw/master/data-raw/EIU%20Democracy%20Index%202020.csv"
datademo=pd.read_csv(link2)
datademo
# Out:
#        country   eiu  year
# 0       Canada  8.87  2021
# 1       Canada  9.24  2020
# 2       Canada  9.22  2019
# 3       Canada  9.15  2018
# 4       Canada  9.15  2017
# ...        ...   ...   ...
# 2333  Zimbabwe  2.67  2012
# 2334  Zimbabwe  2.68  2011
# 2335  Zimbabwe  2.64  2010
# 2336  Zimbabwe  2.53  2008
# 2337  Zimbabwe  2.62  2006
#
# [2338 rows x 3 columns]

# %%
datademo=datademo.pivot(index='country', columns='year', values='eiu')
datademo.reset_index(inplace=True)
datademo
# Out:
# year      country  2006  2008  2010  2011  2012  2013  2014  2015  2016  2017  \
# 0     Afghanistan  3.06  3.02  2.48  2.48  2.48  2.48  2.77  2.77  2.55  2.55
# 1         Albania  5.91  5.91  5.86  5.81  5.67  5.67  5.67  5.91  5.91  5.98
# 2         Algeria  3.17  3.32  3.44  3.44  3.83  3.83  3.83  3.95  3.56  3.56
# 3          Angola  2.41  3.35  3.32  3.32  3.35  3.35  3.35  3.35  3.40  3.62
# 4       Argentina  6.63  6.63  6.84  6.84  6.84  6.84  6.84  7.02  6.96  6.96
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 162       Vietnam  2.75  2.53  2.94  2.96  2.89  3.29  3.41  3.53  3.38  3.08
# 163         Yemen  2.98  2.95  2.64  2.57  3.12  2.79  2.79  2.24  2.07  2.07
# 164        Zambia  5.25  5.25  5.68  6.19  6.26  6.26  6.39  6.28  5.99  5.68
# 165      Zimbabwe  2.62  2.53  2.64  2.68  2.67  2.67  2.78  3.05  3.05  3.16
# 166      eSwatini  2.93  3.04  2.90  3.26  3.20  3.20  3.09  3.09  3.03  3.03
#
# year  2018  2019  2020  2021
# ...

# %%
datademo.columns
# Out:
# Index(['country',      2006,      2008,      2010,      2011,      2012,
#             2013,      2014,      2015,      2016,      2017,      2018,
#             2019,      2020,      2021],
#       dtype='object', name='year')

# %%
datademo.columns=[str(y) for y in datademo.columns]
datademo.columns
# Out:
# Index(['country', '2006', '2008', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
datademo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   country  167 non-null    object
#  1   2006     167 non-null    float64
#  2   2008     167 non-null    float64
#  3   2010     167 non-null    float64
#  4   2011     167 non-null    float64
#  5   2012     167 non-null    float64
#  6   2013     167 non-null    float64
#  7   2014     167 non-null    float64
#  8   2015     167 non-null    float64
#  9   2016     167 non-null    float64
#  10  2017     167 non-null    float64
#  11  2018     167 non-null    float64
#  12  2019     167 non-null    float64
#  13  2020     167 non-null    float64
#  14  2021     167 non-null    float64
# dtypes: float64(14), object(1)
# memory usage: 19.7+ KB

# %%
sinmatchDATA=list(set(datademo.country)- set(WorldMap.NAME))
sinmatchMAP=list(set(WorldMap.NAME)-set(datademo.country) )
len(sinmatchDATA), len(sinmatchMAP)
# Out:
# (22, 101)

# %%
from thefuzz import process
[(process.extractOne(country,sinmatchMAP),country) for country in sorted(sinmatchDATA)]
# Out:
# [(('Bosnia and Herzegovina', 95), 'Bosnia and Hercegovina'),
#  (('Cape Verde', 80), 'Cabo Verde'),
#  (('Congo', 90), 'Congo (Brazzaville)'),
#  (("Cote d'Ivoire", 96), 'Côte d’Ivoire'),
#  (('Democratic Republic of the Congo', 95), 'Democratic Republic of Congo'),
#  (('Iran (Islamic Republic of)', 90), 'Iran'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'Kyrgyz Republic'),
#  (("Lao People's Democratic Republic", 68), 'Laos'),
#  (('Libyan Arab Jamahiriya', 90), 'Libya'),
#  (('Republic of Moldova', 90), 'Moldova'),
#  (('Libyan Arab Jamahiriya', 64), 'Myanmar'),
#  (("Korea, Democratic People's Republic of", 86), 'North Korea'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'North Macedonia'),
#  (('South Georgia South Sandwich Islands', 86), 'South Korea'),
#  (('Syrian Arab Republic', 90), 'Syria'),
#  (('United Republic of Tanzania', 90), 'Tanzania'),
#  (('Timor-Leste', 100), 'Timor Leste'),
#  (('Guadeloupe', 60), 'UAE'),
#  (('Guam', 45), 'UK'),
# ...

# %% [markdown]
# ## Corrigiendo texto clave

# %%
WorldMap.loc[WorldMap.NAME=="Kyrgyzstan","NAME"]="Kyrgyz Republic"
WorldMap.loc[WorldMap.NAME=="Korea, Democratic People's Republic of","NAME"]="North Korea"
WorldMap.loc[WorldMap.NAME=="Korea, Republic of","NAME"]="South Korea"
WorldMap.loc[WorldMap.NAME=="Burma","NAME"]="Myanmar"
WorldMap.loc[WorldMap.NAME=="United Arab Emirates","NAME"]="UAE"
WorldMap.loc[WorldMap.NAME=="United Kingdom","NAME"]="UK"
WorldMap.loc[WorldMap.NAME=="United States","NAME"]="US"

# %%
sinmatchDATA=list(set(datademo.country)- set(WorldMap.NAME))
sinmatchMAP=list(set(WorldMap.NAME)-set(datademo.country) )
len(sinmatchDATA), len(sinmatchMAP)
# Out:
# (15, 94)

# %%
[(process.extractOne(country,sinmatchMAP),country) for country in sorted(sinmatchDATA)]
# Out:
# [(('Bosnia and Herzegovina', 95), 'Bosnia and Hercegovina'),
#  (('Cape Verde', 80), 'Cabo Verde'),
#  (('Congo', 90), 'Congo (Brazzaville)'),
#  (("Cote d'Ivoire", 96), 'Côte d’Ivoire'),
#  (('Democratic Republic of the Congo', 95), 'Democratic Republic of Congo'),
#  (('Iran (Islamic Republic of)', 90), 'Iran'),
#  (("Lao People's Democratic Republic", 68), 'Laos'),
#  (('Libyan Arab Jamahiriya', 90), 'Libya'),
#  (('Republic of Moldova', 90), 'Moldova'),
#  (('The former Yugoslav Republic of Macedonia', 86), 'North Macedonia'),
#  (('Syrian Arab Republic', 90), 'Syria'),
#  (('United Republic of Tanzania', 90), 'Tanzania'),
#  (('Timor-Leste', 100), 'Timor Leste'),
#  (('Viet Nam', 93), 'Vietnam'),
#  (('Swaziland', 59), 'eSwatini')]

# %%
# dict de cambios:
cambiosMapaName={process.extractOne(country,sinmatchMAP)[0]:country for country in sorted(sinmatchDATA)}
cambiosMapaName
# Out:
# {'Bosnia and Herzegovina': 'Bosnia and Hercegovina',
#  'Cape Verde': 'Cabo Verde',
#  'Congo': 'Congo (Brazzaville)',
#  "Cote d'Ivoire": 'Côte d’Ivoire',
#  'Democratic Republic of the Congo': 'Democratic Republic of Congo',
#  'Iran (Islamic Republic of)': 'Iran',
#  "Lao People's Democratic Republic": 'Laos',
#  'Libyan Arab Jamahiriya': 'Libya',
#  'Republic of Moldova': 'Moldova',
#  'The former Yugoslav Republic of Macedonia': 'North Macedonia',
#  'Syrian Arab Republic': 'Syria',
#  'United Republic of Tanzania': 'Tanzania',
#  'Timor-Leste': 'Timor Leste',
#  'Viet Nam': 'Vietnam',
#  'Swaziland': 'eSwatini'}

# %%
# ejecutando cambios 
WorldMap.NAME.replace(cambiosMapaName,inplace=True)

# %% [markdown]
# ## Preparando mapa

# %%
# merge hacia MAPA
WorldMap=WorldMap.merge(datademo, left_on='NAME', right_on="country")

# %%
WorldMap
# Out:
#     FIPS ISO2 ISO3   UN         NAME    AREA    POP2005  REGION  SUBREGION  \
# 0     AG   DZ  DZA   12      Algeria  238174   32854159       2         15
# 1     AJ   AZ  AZE   31   Azerbaijan    8260    8352021     142        145
# 2     AL   AL  ALB    8      Albania    2740    3153731     150         39
# 3     AM   AM  ARM   51      Armenia    2820    3017661     142        145
# 4     AO   AO  AGO   24       Angola  124670   16095214       2         17
# ..   ...  ...  ...  ...          ...     ...        ...     ...        ...
# 162   ID   ID  IDN  360    Indonesia  181157  226063044     142         35
# 163   AE   AE  ARE  784          UAE    8360    4104291     142        145
# 164   TT   TL  TLS  626  Timor Leste    1487    1067285     142         35
# 165   RB   RS  SRB  688       Serbia       0    9863026     150         39
# 166   TW   TW  TWN  158       Taiwan       0          0       0          0
#
# ...

# %% [markdown]
# ## Analisis de variables

# %%
cols1=['2006', '2011', '2016', '2021']
WorldMap[cols1].describe()
# Out:
#              2006        2011        2016        2021
# count  167.000000  167.000000  167.000000  167.000000
# mean     5.519281    5.490539    5.520060    5.281377
# std      2.257950    2.179199    2.196616    2.314036
# min      1.030000    1.080000    1.080000    0.320000
# 25%      3.470000    3.535000    3.580000    3.210000
# 50%      5.890000    5.840000    5.730000    5.610000
# 75%      7.375000    7.190000    7.265000    7.095000
# max      9.880000    9.800000    9.930000    9.750000

# %%
WorldMap[cols1].boxplot(vert=False)
# Out:
# <AxesSubplot:>

# %%
WorldMap[cols1].hist()
# Out:
# array([[<AxesSubplot:title={'center':'2006'}>,
#         <AxesSubplot:title={'center':'2011'}>],
#        [<AxesSubplot:title={'center':'2016'}>,
#         <AxesSubplot:title={'center':'2021'}>]], dtype=object)

# %% [markdown]
# ## Analisis Espacial de "spots"

# %%
import matplotlib.pyplot as plt  # Graphics
from matplotlib import colors
import seaborn                   # Graphics
from pysal.explore import esda   # Exploratory Spatial analytics
from pysal.lib import weights
# Out:
# /Users/JoseManuel/opt/anaconda3/envs/spatial/lib/python3.8/site-packages/spaghetti/network.py:36: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(f"{dep_msg}", FutureWarning)

# %% [markdown]
# ## Coropletico:

# %%
f, ax = plt.subplots(1, figsize=(12, 12))
WorldMap.plot(column='2011', 
        cmap='viridis', 
        scheme='equal_interval',
        k=5, 
        edgecolor='white', 
        linewidth=0., 
        alpha=0.75, 
        legend=True,
        legend_kwds=dict(loc=2),
        ax=ax
       )

ax.set_axis_off()

# %% [markdown]
# ### Cómo saber si un distrito tiene algun parecido a sus vecinos?

# %%
#wQ = weights.contiguity.Queen.from_dataframe(WorldMap)
wKNN=weights.distance.KNN.from_dataframe(WorldMap, k=8)

# %%
# vecindad será valor entre 0 y 1
wKNN.transform = 'R'

# %%
# hay islas?
wKNN.islands
# Out:
# []

# %%
# El lag: como se comporta variable en sus vecinos
WorldMap['w_2011'] = weights.spatial_lag.lag_spatial(wKNN, WorldMap['2011'])

# %%
# standarizando  x y lagx
zscore = lambda x : (x-x.mean())/x.std()
WorldMap[['z_2011','z_w_2011']]=WorldMap[['2011','w_2011']].apply(zscore)

# %%
# x y xlag , por cuadrantes
seaborn.scatterplot(data=WorldMap, x='z_2011', y='z_w_2011')
plt.axvline(0, c='k', alpha=0.5)
plt.axhline(0, c='k', alpha=0.5)

# %% [markdown]
# ### Coeficiente de correlación para cada distrito con significancia estadística?

# %%
lisa2011 = esda.moran.Moran_Local(y=WorldMap['2011'],
                                 w=wKNN,
                                permutations=1000,
                                seed=123)

# guardando coeficiente de cada distrito
WorldMap['lisa2011'] = lisa2011.Is

# %%
# como está el LISA:
ax = seaborn.kdeplot(WorldMap['lisa2011'])
seaborn.rugplot(WorldMap['lisa2011'], ax=ax)
# Out:
# <AxesSubplot:xlabel='lisa2011', ylabel='Density'>

# %% [markdown]
# ### LISA por cuadrante

# %%
# tipo de spots: HH=1, LH=2, LL=3, HL=4
pd.Series(lisa2011.q).value_counts()
# Out:
# 1    65
# 3    64
# 4    28
# 2    10
# dtype: int64

# %%
# guardando cuadrante:
q_labels = ['Q1', 'Q2', 'Q3', 'Q4']
labels = [q_labels[i-1] for i in lisa2011.q]
WorldMap=WorldMap.assign(Cuadrantes_2011=labels)
WorldMap[['Cuadrantes_2011']]
# Out:
#     Cuadrantes_2011
# 0                Q3
# 1                Q3
# 2                Q1
# 3                Q3
# 4                Q3
# ..              ...
# 162              Q4
# 163              Q3
# 164              Q1
# 165              Q1
# 166              Q4
#
# [167 rows x 1 columns]

# %%
# cuales son sig?
lisa2011.p_sim
# Out:
# array([0.48551449, 0.003996  , 0.08391608, 0.01198801, 0.07892108,
#        0.03996004, 0.11088911, 0.000999  , 0.05794206, 0.05994006,
#        0.04195804, 0.18381618, 0.05194805, 0.08791209, 0.08591409,
#        0.25774226, 0.15784216, 0.31468531, 0.000999  , 0.02497502,
#        0.06993007, 0.13686314, 0.000999  , 0.05394605, 0.05594406,
#        0.001998  , 0.000999  , 0.36563437, 0.07192807, 0.13786214,
#        0.000999  , 0.1998002 , 0.01298701, 0.16983017, 0.000999  ,
#        0.000999  , 0.35964036, 0.11988012, 0.14085914, 0.000999  ,
#        0.01298701, 0.02597403, 0.002997  , 0.31168831, 0.002997  ,
#        0.00999001, 0.01298701, 0.01498501, 0.01298701, 0.000999  ,
#        0.07192807, 0.001998  , 0.08291708, 0.05494505, 0.000999  ,
#        0.16183816, 0.14485514, 0.01898102, 0.23176823, 0.18081918,
#        0.27272727, 0.01698302, 0.03396603, 0.000999  , 0.02997003,
#        0.000999  , 0.12987013, 0.002997  , 0.14885115, 0.06193806,
# ...

# %%
seaborn.histplot(lisa2011.p_sim)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# guardando LISAs significativos
lisaSig2011 = 1 * (lisa2011.p_sim < 0.05) # de True/False a 1/0
labels = ['no-sig', 'significativo']  
labels = [labels[i] for i in lisaSig2011]
WorldMap=WorldMap.assign(Sig2011=labels)
WorldMap[['Sig2011']]
# Out:
#            Sig2011
# 0           no-sig
# 1    significativo
# 2           no-sig
# 3    significativo
# 4           no-sig
# ..             ...
# 162         no-sig
# 163  significativo
# 164         no-sig
# 165         no-sig
# 166         no-sig
#
# [167 rows x 1 columns]

# %% [markdown]
# ### Spots  (LISA significativo)

# %%
# encontrando spots

hotSpot = 1 * (lisaSig2011 * lisa2011.q==1)
coldOutlier = 2 * (lisaSig2011 * lisa2011.q==2)
coldSpot = 3 * (lisaSig2011 * lisa2011.q==3)
hotOutlier = 4 * (lisaSig2011 * lisa2011.q==4)

spots = hotSpot + coldSpot + coldOutlier + hotOutlier
spot_labels = [ '0 no_sig', '1 hotSpot', '2 coldOutlier', '3 coldSpot', '4 hotOutlier']
labels = [spot_labels[i] for i in spots]
WorldMap=WorldMap.assign(Spots2011=labels)
WorldMap[['Spots2011']]
# Out:
#       Spots2011
# 0      0 no_sig
# 1    3 coldSpot
# 2      0 no_sig
# 3    3 coldSpot
# 4      0 no_sig
# ..          ...
# 162    0 no_sig
# 163  3 coldSpot
# 164    0 no_sig
# 165    0 no_sig
# 166    0 no_sig
#
# [167 rows x 1 columns]

# %% [markdown]
# ### escenario global

# %%
# 4 graficas
f, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 12))
axs = axs.flatten()

# COROPLETICO DEL LISA #
ax = axs[0]
WorldMap.plot(column='lisa2011', 
                 cmap='plasma', 
                 scheme='equal_interval',
                 k=5,
                 edgecolor='white',
                 linewidth=0.1, 
                 alpha=0.75,
                 legend=True, 
                 ax=ax)

# CUADRANTES #
ax = axs[1]
hmap = colors.ListedColormap([ 'red', 'lightblue', 'blue', 'pink'])
WorldMap.plot(column='Cuadrantes_2011', 
                 categorical=True,
                 cmap=hmap,
                 linewidth=0.1, 
                 ax=ax,
                 edgecolor='white',
                 legend=True)

# LISA SIGNIFICATIVO #

ax = axs[2]
hmap = colors.ListedColormap(['grey','black'])
WorldMap.plot(column='Sig2011',
                 categorical=True,
                 cmap=hmap, linewidth=0.1, ax=ax,
                 edgecolor='white', legend=True)

                       
# LISA SPOTS #
ax = axs[3]

hmap = colors.ListedColormap([ 'white', 'red', 'lightblue', 'blue', 'pink'])
WorldMap.plot(column='Spots2011',
                 categorical=True,
                 cmap=hmap,
                 linewidth=0.1, ax=ax,
                 edgecolor='white', legend=True)

for i, ax in enumerate(axs.flatten()):
    ax.set_axis_off()
    ax.set_title(['Coropletico Autocorrelacion local', 
                  'Cuadrantes', 
                  'significativoS', 
                  'Spots '][i], y=0)

f.tight_layout()

plt.show()

# %%
# guardando data
WorldMap.to_file("WorldMapLisa.gpkg", layer='DISTRITO', driver="GPKG")

# %%
from esda.moran import Moran_BV, Moran_Local_BV
from splot.esda import plot_moran_bv_simulation, plot_moran_bv

# %%
moran_loc_bv = Moran_Local_BV(WorldMap['2021'], WorldMap['2011'], wKNN)

# %%
from splot.esda import moran_scatterplot,plot_local_autocorrelation

fig, ax = moran_scatterplot(moran_loc_bv, p=0.05)
ax.set_xlabel('2021')
ax.set_ylabel('Spatial lag of 2011')
plt.show()

# %%
moran_loc_bv

# %%
plot_local_autocorrelation(moran_loc_bv, WorldMap, '2011')
plt.show()
